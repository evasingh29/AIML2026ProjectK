# %%
GROUP_NAME = "IowaGPT"
NAME = "Amit Boodhoo, Diego Liogon, Eva Singh, Kate Meyer"
PROJECT_NAME = "Project S"
USAGE_OF_CHATGPT = " "

# %% [markdown]
# ## Introduction
#
# **Task:**
# Define if this is **Classification** (predicting a category) or **Regression** (predicting a number).
#
# **Dataset Source:**
# Provide a link to the dataset (Kaggle, UCI, etc.). Example: [Dataset Link](URL_HERE)
#
# **Goal:**
# Explain what you are trying to predict. Example: "Predicting if a used car will sell above $10,000 based on mileage."

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection as skms
from sklearn import metrics
# Import your specific models here (RandomForest, KNN, etc.)

# %% [markdown]
# ## Methods – Data
#
# **Features:**
# List and briefly describe the columns in your dataset. For example:
# - `age` – Age of the individual in years
# - `height` – Height in cm
# - `activity_level` – Categorical feature describing activity intensity
#
# **Data Cleaning Steps:**
# Explain any preprocessing you did. For example:
# - Handling missing values (NaNs) – e.g., filled with mean/median or dropped rows
# - Encoding categorical variables – e.g., one-hot encoding for `activity_level`
# - Normalization or scaling – e.g., scaled numeric features to 0–1 range

# %%
# 1. Load Data
df = pd.read_csv('your_dataset.csv')

# 2. Cleaning (Reuse your logic!)
# df['col'] = df['col'].fillna(value)
# df['cat'] = df['cat'].map({...})

# 3. Train/Test/Val Split (Rubric requires this!)
# Use an 80/20 or 70/15/15 split.

# %% [markdown]
# ## Methods – Training/Validation
#
# **Model Variations Tested:**
# We tested at least 5 different variations of our model to find the best-performing configuration.
#
# **Hyperparameters Tuned:**
# List the hyperparameters you adjusted for each model. For example:
# - `k` in K-Nearest Neighbors
# - `max_depth` in Decision Trees
# - `alpha` in Naive Bayes
# - `learning_rate` in Gradient Boosting
# - `n_estimators` in Random Forest
#
# **Validation Approach:**
# Briefly describe how you validated your models, e.g., using a validation set or k-fold cross-validation.

# %%
models_to_try = {
    "Baseline": DummyClassifier(),
    "Model 2": DecisionTreeClassifier(max_depth=5),
    "Model 3": DecisionTreeClassifier(max_depth=15),
    "Model 4": RandomForestClassifier(n_estimators=100),
    "Model 5": KNeighborsClassifier(n_neighbors=5)
}
# Loop through and print CV scores

# %% [markdown]
# ## Results on Test Set
#
# **Selected Model:**
# State the model you picked as the winner from Cell 7. Example: "K-Nearest Neighbors with k=50"
#
# **Evaluation on Test Set:**
# Evaluate the model on data it has never seen. Include at least one of the following:
# - Confusion Matrix
# - ROC Curve
#
# **Example Code (Python/Sklearn):**
# ```python
# from sklearn.metrics import confusion_matrix, plot_confusion_matrix, roc_curve, auc
#
# # predictions = best_model.predict(X_test)
# # y_true = y_test
#
# # Confusion Matrix
# cm = confusion_matrix(y_true, predictions)
# print(cm)
#
# # Optional: Plot confusion matrix
# # plot_confusion_matrix(best_model, X_test, y_test)

# %% [markdown]
# ## Discussion & Conclusion Cell 9
#
# **Best Model:**
# The KNN model with k=50 performed the best. It achieved the highest accuracy and handled the non-linear patterns in the biometric data better than the other models.
#
# **Limitations:**
# - Some features were highly correlated, which likely affected the performance of Naive Bayes.
# - Cleaning the dataset took longer than expected due to missing values and encoding categorical variables.
#
# **Impressions / Takeaways:**
# - `avg_heart_rate` turned out to be surprisingly important for distinguishing between activity classes.
# - The KNN model was quite sensitive to the choice of k, which shows how important hyperparameter tuning is.

# %% [markdown]
# ## Disclosures
#
# **Use of AI / ChatGPT:**
# Describe how you used AI for this project. Example:
# - "ChatGPT was used to help structure the code, suggest Markdown templates, and debug minor syntax issues."
# - "All analysis, decisions on hyperparameters, and interpretations were done by me."
#
# **Academic Integrity Note:**
# - Be honest about AI assistance.
# - Emphasize that final decisions, evaluations, and conclusions are your own.
